# %% [markdown]
# Q1. Write a Python function that takes in two arrays of data and calculates the F-value for a variance ratio
# test. The function should return the F-value and the corresponding p-value for the test.

# %%
import scipy.stats as stats

def variance_ratio_test(data1, data2):
    """
    Perform a variance ratio test (F-test) for two sets of data.

    Parameters:
    - data1: Array-like, the first set of data.
    - data2: Array-like, the second set of data.

    Returns:
    - f_value: The calculated F-value.
    - p_value: The corresponding p-value.
    """
    # Calculate variances
    var1 = np.var(data1, ddof=1)  # ddof=1 for sample variance
    var2 = np.var(data2, ddof=1)

    # Perform F-test
    f_value = var1 / var2 if var1 > var2 else var2 / var1
    df1 = len(data1) - 1
    df2 = len(data2) - 1
    p_value = 2 * min(stats.f.cdf(f_value, df1, df2), 1 - stats.f.cdf(f_value, df1, df2))

    return f_value, p_value

# Example usage:
data1 = [12, 15, 18, 21, 24]
data2 = [10, 14, 16, 20, 22]

f_value, p_value = variance_ratio_test(data1, data2)

print(f'F-Value: {f_value:.4f}')
print(f'P-Value: {p_value:.4f}')

# %% [markdown]
# Q2. Given a significance level of 0.05 and the degrees of freedom for the numerator and denominator of an
# F-distribution, write a Python function that returns the critical F-value for a two-tailed test.

# %%
import scipy.stats as stats

def critical_f_value(alpha, df_num, df_denom):
    """
    Calculate the critical F-value for a two-tailed test given a significance level
    and degrees of freedom for the numerator and denominator.

    Parameters:
    - alpha: Significance level (e.g., 0.05 for a 95% confidence level).
    - df_num: Degrees of freedom for the numerator.
    - df_denom: Degrees of freedom for the denominator.

    Returns:
    - critical_f: The critical F-value.
    """
    alpha_half = alpha / 2  # Two-tailed test, so split alpha in half

    # Use the ppf (percent point function) to find the critical F-value
    critical_f = stats.f.ppf(1 - alpha_half, df_num, df_denom)

    return critical_f

# Example usage:
alpha = 0.05
df_num = 2
df_denom = 15

critical_f = critical_f_value(alpha, df_num, df_denom)

print(f'Critical F-Value: {critical_f:.4f}')

# %% [markdown]
# Q3. Write a Python program that generates random samples from two normal distributions with known
# variances and uses an F-test to determine if the variances are equal. The program should output the Fvalue, degrees of freedom, and p-value for the test.

# %%
import numpy as np
import scipy.stats as stats

def f_test_for_equal_variances(sample1, sample2):
    """
    Perform an F-test for equal variances.

    Parameters:
    - sample1: Array-like, the first sample.
    - sample2: Array-like, the second sample.

    Returns:
    - f_value: The calculated F-value.
    - df1: Degrees of freedom for the numerator.
    - df2: Degrees of freedom for the denominator.
    - p_value: The corresponding p-value.
    """
    var1 = np.var(sample1, ddof=1)  # ddof=1 for sample variance
    var2 = np.var(sample2, ddof=1)

    # Perform F-test
    if var1 > var2:
        f_value = var1 / var2
        df1 = len(sample1) - 1
        df2 = len(sample2) - 1
    else:
        f_value = var2 / var1
        df1 = len(sample2) - 1
        df2 = len(sample1) - 1

    p_value = 2 * min(stats.f.cdf(f_value, df1, df2), 1 - stats.f.cdf(f_value, df1, df2))

    return f_value, df1, df2, p_value

# Generate random samples from normal distributions with known variances
np.random.seed(42)
sample_size = 30
variance1 = 4
variance2 = 6

sample1 = np.random.normal(0, np.sqrt(variance1), sample_size)
sample2 = np.random.normal(0, np.sqrt(variance2), sample_size)

# Perform F-test for equal variances
f_value, df1, df2, p_value = f_test_for_equal_variances(sample1, sample2)

# Print results
print(f'F-Value: {f_value:.4f}')
print(f'Degrees of Freedom (numerator): {df1}')
print(f'Degrees of Freedom (denominator): {df2}')
print(f'P-Value: {p_value:.4f}')

# %% [markdown]
# Q4.The variances of two populations are known to be 10 and 15. A sample of 12 observations is taken from
# each population. Conduct an F-test at the 5% significance level to determine if the variances are
# significantly different.

# %%
import scipy.stats as stats

# Given data
variance1 = 10
variance2 = 15
sample_size = 12
significance_level = 0.05

# Degrees of freedom
df1 = sample_size - 1
df2 = sample_size - 1

# F-statistic formula
f_statistic = variance1 / variance2

# Critical F-value for a two-tailed test
critical_f = stats.f.ppf(1 - significance_level / 2, df1, df2)

# Two-tailed p-value
p_value = 2 * min(stats.f.cdf(f_statistic, df1, df2), 1 - stats.f.cdf(f_statistic, df1, df2))

# Print results
print(f'F-Statistic: {f_statistic:.4f}')
print(f'Critical F-Value: {critical_f:.4f}')
print(f'P-Value: {p_value:.4f}')

# Compare with critical F-value
if abs(f_statistic) > critical_f:
    print('Reject the null hypothesis. The variances are significantly different.')
else:
    print('Fail to reject the null hypothesis. There is not enough evidence to conclude significant differences in variances.')

# %% [markdown]
# Q5. A manufacturer claims that the variance of the diameter of a certain product is 0.005. A sample of 25
# products is taken, and the sample variance is found to be 0.006. Conduct an F-test at the 1% significance
# level to determine if the claim is justified.

# %%
import scipy.stats as stats

# Given data
claimed_variance = 0.005
sample_variance = 0.006
sample_size = 25
significance_level = 0.01

# Degrees of freedom
df1 = sample_size - 1  # degrees of freedom for the numerator
df2 = 1               # degrees of freedom for the denominator

# F-statistic formula
f_statistic = sample_variance / claimed_variance

# Critical F-value for a two-tailed test
critical_f = stats.f.ppf(1 - significance_level / 2, df1, df2)

# Two-tailed p-value
p_value = 2 * min(stats.f.cdf(f_statistic, df1, df2), 1 - stats.f.cdf(f_statistic, df1, df2))

# Print results
print(f'F-Statistic: {f_statistic:.4f}')
print(f'Critical F-Value: {critical_f:.4f}')
print(f'P-Value: {p_value:.4f}')

# Compare with critical F-value
if abs(f_statistic) > critical_f:
    print('Reject the null hypothesis. The claimed variance is not justified.')
else:
    print('Fail to reject the null hypothesis. There is not enough evidence to conclude the claimed variance is unjustified.')

# %% [markdown]
# Q6. Write a Python function that takes in the degrees of freedom for the numerator and denominator of an
# F-distribution and calculates the mean and variance of the distribution. The function should return the
# mean and variance as a tuple

# %%
def f_distribution_mean_and_variance(df1, df2):
    """
    Calculate the mean and variance of an F-distribution.

    Parameters:
    - df1: Degrees of freedom for the numerator.
    - df2: Degrees of freedom for the denominator.

    Returns:
    - mean: Mean of the F-distribution.
    - variance: Variance of the F-distribution.
    """
    mean = df2 / (df2 - 2)
    variance = (2 * df2**2 * (df1 + df2 - 2)) / (df1 * (df2 - 2)**2 * (df2 - 4))

    return mean, variance

# Example usage:
df1_example = 5
df2_example = 10

mean, variance = f_distribution_mean_and_variance(df1_example, df2_example)

print(f'Mean of F-distribution: {mean:.4f}')
print(f'Variance of F-distribution: {variance:.4f}')

# %% [markdown]
# Q7. A random sample of 10 measurements is taken from a normal population with unknown variance. The
# sample variance is found to be 25. Another random sample of 15 measurements is taken from another
# normal population with unknown variance, and the sample variance is found to be 20. Conduct an F-test
# at the 10% significance level to determine if the variances are significantly different.

# %%
import scipy.stats as stats

# Given data
sample_var1 = 25
sample_size1 = 10
sample_var2 = 20
sample_size2 = 15
significance_level = 0.10

# Degrees of freedom
df1 = sample_size1 - 1
df2 = sample_size2 - 1

# F-statistic formula
f_statistic = sample_var1 / sample_var2

# Critical F-value for a two-tailed test
critical_f = stats.f.ppf(1 - significance_level / 2, df1, df2)

# Two-tailed p-value
p_value = 2 * min(stats.f.cdf(f_statistic, df1, df2), 1 - stats.f.cdf(f_statistic, df1, df2))

# Print results
print(f'F-Statistic: {f_statistic:.4f}')
print(f'Critical F-Value: {critical_f:.4f}')
print(f'P-Value: {p_value:.4f}')

# Compare with critical F-value
if abs(f_statistic) > critical_f:
    print('Reject the null hypothesis. The variances are significantly different.')
else:
    print('Fail to reject the null hypothesis. There is not enough evidence to conclude significant differences in variances.')
